# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Enable inline plotting
# %matplotlib inline

# %%
df_advanced = pd.read_csv("archive/advanced.csv")
df_advanced
# Out:
#        seas_id  season  player_id          player  birth_year    hof  pos  \
# 0        28943    2021       4219    Aaron Gordon         NaN  False   PF
# 1        28944    2021       4582   Aaron Holiday         NaN  False   PG
# 2        28945    2021       4805   Aaron Nesmith         NaN  False   SF
# 3        28946    2021       4463     Abdel Nader         NaN  False   SF
# 4        28947    2021       4687     Adam Mokoka         NaN  False   SG
# ...        ...     ...        ...             ...         ...    ...  ...
# 29449      200    1947        157     Walt Miller         NaN  False    F
# 29450      201    1947        158   Warren Fenley         NaN  False    F
# 29451      202    1947        159   Wilbert Kautz         NaN  False  G-F
# 29452      203    1947        160  Woody Grimshaw         NaN  False    G
# 29453      204    1947        161     Wyndol Gray         NaN  False  G-F
#
#         age  experience   lg  ... tov_percent  usg_percent  ows  dws   ws  \
# ...
